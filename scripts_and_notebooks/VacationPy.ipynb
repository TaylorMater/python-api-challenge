# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests



#importing a bunch of other stuff while trying to find a way to generate this map
#I guess I missed the class lecture (I missed one while sick) that reviewed this stuff, because this feels kind of out of the blue to just use a library I've never used to such depth

import holoviews as hv

import geopandas as gpd

import geoviews as gv

from cartopy import crs

gv.extension('bokeh')

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1854'>
#   <div id="b46b9e45-0784-4ab1-afdc-5317cd8ce82e" data-root-id="p1854" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       saipan  15.2123  145.7545    298.23        65          75
# 1        1     heunghae  36.1095  129.3452    276.43        78          59
# 2        2    adamstown -25.0660 -130.1015    296.55        86         100
# 3        3  port alfred -33.5860   26.8833    296.63        80         100
# 4        4       bethel  60.7922 -161.7558    244.16        83           0
#
#    Wind Speed Country        Date
# 0        7.72      MP  1706620174
# 1        1.61      KR  1706620175
# 2        8.47      PN  1706620176
# 3        2.24      ZA  1706620177
# 4        3.60      US  1706620177

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
############################
# Test Cell
############################


#this doesn't work
# city_data_df.hvplot(tiles='OSM', hover_cols=['Lat', 'Lng', 'City', 'Humidity'], size='Humidity', alpha= 0.7, cmap='RdYlBu', width=800, height=500)

# %%
# %%capture --no-display


# Configure the map plot



#after scouring the internet for a long time, I ended up asking chat-gpt to tell me how to use geoviews/geopandas/hvplot to create a visual

#I apologize, because I'm unable to cite the sources that way, and it feels like an intellectual crutch to rely on it. But it saved me so much time trying to read example documentation for the libraries I don't know anything about

geometry = gpd.points_from_xy(city_data_df['Lng'], city_data_df['Lat'])
geo_df = gpd.GeoDataFrame(city_data_df, geometry=geometry)

#defining open street map tile source
osm_tile = gv.tile_sources.OSM()

#plot the cities
plot = geo_df.hvplot(geo=True, tiles=osm_tile, hover_cols=['Lng', 'Lat' 'City', 'Humidity'], size='Humidity', alpha= 0.7, color='Humidity', cmap='RdYlBu', width=800, height=500)



# Display the map
display(plot)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (Humidity,Lng)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#I don't have an ideal weather condition, so I am using the defaults provided

#fyi, 27 c = 300 k (0 K ~= -273 C, at 1:1 from there)


#max temp range from 294-300 kelvin
city_data_df = city_data_df[(city_data_df['Max Temp'] > 294) & city_data_df['Max Temp'] < 300]

city_data_df = city_data_df[city_data_df['Wind Speed'] < 4.5]

city_data_df = city_data_df[city_data_df['Cloudiness'] == 0]

# Drop any rows with null values
city_data_df.dropna()

#count how many rows are left
print(city_data_df.shape[0])

# Display sample data
city_data_df.head()
# Out:
# 48
#     City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 4         4                  bethel  60.7922 -161.7558    244.16        83
# 17       17           blackmans bay -43.0031  147.3169    289.83        75
# 25       25  hawaiian paradise park  19.5933 -154.9731    294.28        89
# 42       42         stjordalshalsen  63.4681   10.9262    274.15        60
# 46       46             new norfolk -42.7826  147.0587    289.87        88
#
#     Cloudiness  Wind Speed Country        Date
# 4            0        3.60      US  1706620177
# 17           0        2.67      AU  1706620190
# 25           0        2.57      US  1706620197
# 42           0        1.03      NO  1706620212
# 46           0        1.66      AU  1706620215

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

hotel_df = city_data_df.copy()
hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]
hotel_df.head()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
display(hotel_df)
# Out:
#                        City Country      Lat       Lng  Humidity Hotel Name
# 25   hawaiian paradise park      US  19.5933 -154.9731        89
# 66                     hilo      US  19.7299 -155.0907        64
# 98                   laguna      BR -28.4825  -48.7808        67
# 113            san patricio      MX  19.2253 -104.7045        78
# 187              filadelfia      PY -22.3394  -60.0316        44
# 205                  bonthe      SL   7.5264  -12.5050        54
# 219                vallenar      CL -28.5762  -70.7594        58
# 261               tazacorte      ES  28.6419  -17.9339        60
# 334                imbituba      BR -28.2400  -48.6703        67
# 342            villa gesell      AR -37.2639  -56.9730        58
# 366                   junin      AR -34.5838  -60.9433        29
# 432                 formosa      AR -26.1849  -58.1731        51
# 457                 iquitos      PE  -3.7491  -73.2538        94
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000

categories = 'accommodation.hotel'
limit = 5

params = {
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key 
}

# Print a message to follow up the hotel search
print("Starting hotel search")


#bad practice to use iterrows() if avoidable. But convenient considering the size of this filtered dataframe
# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lng = row['Lng']
    lat = row['Lat']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make an API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# hawaiian paradise park - nearest hotel: No hotel found
# hilo - nearest hotel: Dolphin Bay Hotel
# laguna - nearest hotel: Marina Sul Hotel
# san patricio - nearest hotel: Las Gaviotas
# filadelfia - nearest hotel: Hotel Florida
# bonthe - nearest hotel: No hotel found
# vallenar - nearest hotel: Hotel CECIL
# tazacorte - nearest hotel: Apartamentos Atlantis
# imbituba - nearest hotel: Silvestre Praia Hotel
# villa gesell - nearest hotel: Hotel El Faro
# junin - nearest hotel: Central Hotel
# formosa - nearest hotel: Hotel Plaza
# iquitos - nearest hotel: Hospedaje Las Palmeras
# sombrio - nearest hotel: Hotel São Cristóvão
# am timan - nearest hotel: Nimla
# bella union - nearest hotel: No hotel found
#                        City Country      Lat       Lng  Humidity  \
# 25   hawaiian paradise park      US  19.5933 -154.9731        89
# 66                     hilo      US  19.7299 -155.0907        64
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

geometry = gpd.points_from_xy(hotel_df['Lng'], hotel_df['Lat'])
geo_df = gpd.GeoDataFrame(hotel_df, geometry=geometry)

#defining open street map tile source
osm_tile = gv.tile_sources.OSM()


#plot the cities
plot = geo_df.hvplot(geo=True, tiles=osm_tile, hover_cols=['Lng', 'Lat', 'City', 'Country', 'Humidity', 'Hotel Name'], size='Humidity', alpha= 0.7, color='City', cmap='RdYlGn', width=800, height=500)

# Display the map
display(plot)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Lng,Lat,Country,Hotel Name)

# %%
geometry = gpd.points_from_xy(hotel_df['Lng'], hotel_df['Lat'])
geo_df = gpd.GeoDataFrame(hotel_df, geometry=geometry)

#defining open street map tile source
osm_tile = gv.tile_sources.OSM()


#plot the cities
plot = geo_df.hvplot(geo=True, tiles=osm_tile, hover_cols=['Lng', 'Lat', 'City', 'Country', 'Humidity', 'Hotel Name'], size='Humidity', alpha= 0.7, color='City', cmap='RdYlGn', width=800, height=500)

# Display the map
display(plot)
